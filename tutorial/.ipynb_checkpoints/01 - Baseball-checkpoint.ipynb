# %%
from ggplot import *
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/glamp/repos/yhat/blog/code-exp/22/baseball-data.csv")
df = pd.read_table("/Users/glamp/repos/yhat/blog/code-exp/22/pitches.tsv")
df.ix[:,:15].head()
# Out:
#                   pitch_time  inning top_or_bottom       pitcher_name  \
# 0  2013-10-01 20:07:43 -0400       1           Top  Francisco Liriano
# 1  2013-10-01 20:07:57 -0400       1           Top  Francisco Liriano
# 2  2013-10-01 20:08:12 -0400       1           Top  Francisco Liriano
# 3  2013-10-01 20:08:31 -0400       1           Top  Francisco Liriano
# 4  2013-10-01 20:09:09 -0400       1           Top  Francisco Liriano
#
#      hitter_name pitch_type       x       y  start_speed  end_speed  sz_top  \
# 0  Shin-Soo Choo          B   78.97  164.92         93.2       85.3    3.10
# 1  Shin-Soo Choo          S   82.40  131.24         93.4       85.6    3.06
# 2  Shin-Soo Choo          S   96.14  161.47         89.1       82.8    3.25
# 3  Shin-Soo Choo          S  106.44  163.19         90.0       83.3    3.25
# 4   Ryan Ludwick          B  163.95  194.28         87.7       81.6    3.62
#
#    sz_bottom  pfx_x  pfx_z     px
# 0       1.53  11.01   6.47  0.628
# 1       1.56  10.14   7.99  0.545
# 2       1.53   3.11   4.95  0.120
# 3       1.53  -0.38   2.15 -0.229
# 4       1.78   1.62   1.93 -1.917

# %%
df.ix[:,16:].head()
# Out:
#       x0  y0     ax     ay       az     z0     vx0     vy0     vz0  break_y  \
# 0  1.757  50  5.472 -6.862 -136.338 -6.799  20.562  32.261 -20.022     23.8
# 1  1.711  50  5.650 -6.693 -136.724 -3.800  19.130  31.090 -17.028     23.8
# 2  1.559  50  5.792 -4.763 -130.525 -5.690   5.392  26.060 -23.521     23.8
# 3  1.172  50  5.832 -3.519 -131.909 -5.404  -0.666  28.298 -28.316     23.8
# 4  0.194  50  5.578 -5.886 -128.348 -7.342   2.709  26.078 -28.880     23.8
#
#    break_angle  break_length pitch_type.1  type_confidence  zone  nasty  \
# 0        -41.3           6.3           FT            0.894     9     65
# 1        -44.6           5.4           FT            0.895    12     62
# 2        -10.4           5.8           SL            0.931     8     32
# 3          2.6           6.8           SL            0.926     8     34
# 4         -3.1           7.3           SL            0.915    13     55
#
#    spin_dir  spin_rate comments  unk
# 0   120.583   2541.561      NaN  NaN
# 1   128.371   2589.087      NaN  NaN
# 2   148.073   1133.227      NaN  NaN
# 3   189.793    430.593      NaN  NaN
# 4   140.567    482.080      NaN  NaN

# %%
df['pitch_type'].head()
# Out:
# 0    B
# 1    S
# 2    S
# 3    S
# 4    B
# Name: pitch_type, dtype: object

# %%
df['f_pitch_result'] = np.where(df['pitch_type']=="B", "ball",
                              np.where(df['pitch_type']=="S", "strike",
                                       np.where(df['pitch_type']=="X", "hit", None)))

# %%
lu = """FA,Fastball
FF,Fastball
FT,Fastball
FC,Cut fastball
FS,Fastball (sinker|split-fingered)
SI,Fastball (sinker|split-fingered)
SF,Fastball (sinker|split-fingered)
SL,Slider
CH,Changeup
CB,Curveball
CU,Curveball
KC,Curveball
KN,Knuckleball
EP,Eephus
UN,Unidentified
XX,Unidentified
PO,Pitch out
FO,Pitch out""".split('\n')

# %%
for row in lu:
    row = row.split(',')
    abbrv, name = row[0], row[1]
    df['pitch_type.1'] = df['pitch_type.1'].replace(abbrv, name)
df['f_pitch_type'] = df['pitch_type.1']
df = df[df.f_pitch_type.isin(df.f_pitch_type.value_counts().head(8).index)]

# %%
ggplot(aes(x='start_speed', color='f_pitch_type'), data=df) +\
    geom_density() +\
    scale_color_brewer(type='qual')
# Out:
# <ggplot: (292749257)>

# %%
ggplot(aes(x='start_speed', color='pitch_type'), data=df) +\
    geom_density() +\
    scale_color_brewer(type='qual') +\
    facet_wrap("f_pitch_type")
# Out:
# <ggplot: (286799945)>

# %%
df.ix[:,:15].head()
# Out:
#                   pitch_time  inning top_or_bottom       pitcher_name  \
# 0  2013-10-01 20:07:43 -0400       1           Top  Francisco Liriano
# 1  2013-10-01 20:07:57 -0400       1           Top  Francisco Liriano
# 2  2013-10-01 20:08:12 -0400       1           Top  Francisco Liriano
# 3  2013-10-01 20:08:31 -0400       1           Top  Francisco Liriano
# 4  2013-10-01 20:09:09 -0400       1           Top  Francisco Liriano
#
#      hitter_name pitch_type       x       y  start_speed  end_speed  sz_top  \
# 0  Shin-Soo Choo          B   78.97  164.92         93.2       85.3    3.10
# 1  Shin-Soo Choo          S   82.40  131.24         93.4       85.6    3.06
# 2  Shin-Soo Choo          S   96.14  161.47         89.1       82.8    3.25
# 3  Shin-Soo Choo          S  106.44  163.19         90.0       83.3    3.25
# 4   Ryan Ludwick          B  163.95  194.28         87.7       81.6    3.62
#
#    sz_bottom  pfx_x  pfx_z     px
# 0       1.53  11.01   6.47  0.628
# 1       1.56  10.14   7.99  0.545
# 2       1.53   3.11   4.95  0.120
# 3       1.53  -0.38   2.15 -0.229
# 4       1.78   1.62   1.93 -1.917

# %%
df.ix[:,16:30].head()
# Out:
#       x0  y0     ax     ay       az     z0     vx0     vy0     vz0  break_y  \
# 0  1.757  50  5.472 -6.862 -136.338 -6.799  20.562  32.261 -20.022     23.8
# 1  1.711  50  5.650 -6.693 -136.724 -3.800  19.130  31.090 -17.028     23.8
# 2  1.559  50  5.792 -4.763 -130.525 -5.690   5.392  26.060 -23.521     23.8
# 3  1.172  50  5.832 -3.519 -131.909 -5.404  -0.666  28.298 -28.316     23.8
# 4  0.194  50  5.578 -5.886 -128.348 -7.342   2.709  26.078 -28.880     23.8
#
#    break_angle  break_length pitch_type.1  type_confidence
# 0        -41.3           6.3     Fastball            0.894
# 1        -44.6           5.4     Fastball            0.895
# 2        -10.4           5.8       Slider            0.931
# 3          2.6           6.8       Slider            0.926
# 4         -3.1           7.3       Slider            0.915

# %%
ggplot(aes('px', 'pz'), data=df) +\
    geom_jitter() +\
    geom_hline(color='red', y=[df.sz_top.mean(), df.sz_bottom.mean()]) +\
    geom_vline(color='red', x=[-1, 1]) +\
    xlim(-3, 3) + ylim(0, 6) +\
    coord_equal()
# Out:
# <ggplot: (286937637)>

# %%
df.pitcher_name.value_counts().head(10)
# Out:
# David Price          655
# C.J. Wilson          653
# Francisco Liriano    653
# Justin Verlander     651
# Cliff Lee            638
# Andy Pettitte        632
# Jeff Samardzija      622
# Chris Tillman        622
# James Shields        621
# Alex Cobb            617
# dtype: int64

# %%
pitcher = df[df.pitcher_name=='David Price']

# %%
ggplot(aes(x='inning', y='start_speed'), data=pitcher) +\
    geom_jitter()
# Out:
# <ggplot: (287028549)>

# %%
ggplot(aes(x='inning', y='start_speed', color='f_pitch_type'), data=pitcher) +\
    geom_jitter()
# Out:
# <ggplot: (286307725)>

# %%
ggplot(aes(x='inning', y='start_speed'), data=pitcher) +\
    geom_jitter() +\
    facet_wrap("f_pitch_type")
# Out:
# <ggplot: (286860097)>

# %%
ggplot(aes(x='inning', y='start_speed'), data=pitcher) +\
    geom_jitter() +\
    stat_smooth(method='lm', color='blue') +\
    facet_wrap("f_pitch_type")
# Out:
# <ggplot: (288624421)>

# %%
df['pitch_count'] = 1
df['pitch_count'] = df.groupby("pitcher_name").apply(lambda x: np.cumsum(x['pitch_count']))

# %%
pitcher = df[df.pitcher_name=='C.J. Wilson']
print len(pitcher)
pitcher[['pitcher_name', 'pitch_count']].head()
# Out:
# 653
#       pitcher_name  pitch_count
# 10972  C.J. Wilson            1
# 10973  C.J. Wilson            2
# 10974  C.J. Wilson            3
# 10975  C.J. Wilson            4
# 10976  C.J. Wilson            5

# %%
ggplot(aes(x='pitch_count', y='start_speed'), data=pitcher) +\
    geom_point()
# Out:
# <ggplot: (287022805)>

# %%
ggplot(aes(x='pitch_count', y='start_speed', color='f_pitch_type'), data=pitcher) +\
    geom_point() +\
    stat_smooth(se=False) +\
    scale_color_brewer(type='qual')
# Out:
# <ggplot: (286853457)>

# %%
ggplot(aes(x='px', y='pz', color='pitch_type', shape='f_pitch_type'), data=pitcher) +\
    geom_jitter() +\
    geom_hline(y=[pitcher.sz_bottom.mean(), pitcher.sz_top.mean()], color='red') +\
    geom_vline(x=[-1, 1], color='red') +\
    xlim(-2, 0) + ylim(0, 5) +\
    coord_equal()
# Out:
# <ggplot: (286301077)>

# %%
ggplot(aes(x='break_length'), data=pitcher) + geom_histogram(binwidth=1)
# Out:
# <ggplot: (286801749)>

# %%
ggplot(aes(x='break_length', color='f_pitch_type'), data=pitcher) +\
    geom_histogram(binwidth=1)
# Out:
# <ggplot: (287025541)>

# %%
ggplot(aes(x='break_length', fill='f_pitch_type'), data=pitcher) +\
    geom_histogram(binwidth=1)
# Out:
# <ggplot: (288615865)>

# %%
ggplot(aes(x='break_length',fill='f_pitch_type'), data=pitcher) +\
    geom_histogram(binwidth=1, alpha=0.3, color='black')
# Out:
# <ggplot: (282271333)>

# %%
df_agg = df.groupby(['start_speed', 'end_speed']).pitch_type.value_counts()

# %%
df_agg = df_agg.unstack().fillna(0)

# %%
df['start_speed_bucket'] = pd.cut(df.start_speed, range(45, 100, 5))
df['end_speed_bucket'] = pd.cut(df.start_speed, range(45, 100, 5))

# %%
ggplot(aes(x='start_speed_bucket'), data=df) + geom_bar()
# Out:
# <ggplot: (286664041)>

# %%
ggplot(aes(x='start_speed_bucket'), data=df) + geom_bar() + facet_wrap("f_pitch_type")
# Out:
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ggplot-0.5.6-py2.7.egg/ggplot/ggplot.py:198: RuntimeWarning: Facetting is currently not supported with geom_bar. See
#                     https://github.com/yhat/ggplot/issues/196 for more information
#   warnings.warn(msg, RuntimeWarning)
# <ggplot: (287022777)>

# %%
ggplot(aes(x='x', y='y'), data=df) +\
    geom_point() +\
    coord_equal()
# Out:
# <ggplot: (287583725)>

# %%
ggplot(aes(x='x', y='y', color='pitch_type'), data=df) +\
    geom_jitter() +\
    coord_equal()
# Out:
# <ggplot: (275114721)>

# %%
df.hitter_name.value_counts().head(10)
# Out:
# Mike Trout          570
# Matt Carpenter      564
# Carlos Santana      559
# Joey Votto          542
# Christian Yelich    532
# Shin-Soo Choo       527
# Chris Davis         517
# Kyle Seager         515
# Evan Longoria       513
# Jayson Werth        513
# dtype: int64

# %%
hitter = df[df.hitter_name=='Mike Trout']

# %%
ggplot(aes(x='px', y='pz', color='pitch_type'), data=hitter) +\
    geom_point() +\
    geom_hline(y=[hitter.sz_bottom.mean(), hitter.sz_top.mean()], color='red') +\
    geom_vline(x=[-1, 1], color='red') +\
    xlim(-2, 2) + ylim(0, 4) +\
    coord_equal()
# Out:
# <ggplot: (286453749)>

# %%
ggplot(aes(x='px', y='pz', color='f_pitch_type'), data=hitter) +\
    geom_point() +\
    geom_hline(y=[hitter.sz_bottom.mean(), hitter.sz_top.mean()], color='red') +\
    geom_vline(x=[-1, 1], color='red') +\
    xlim(-2, 2) + ylim(0, 4) +\
    coord_equal()
# Out:
# <ggplot: (290666921)>

# %%
ggplot(aes(x='px', y='pz'), data=hitter) +\
    stat_bin2d() +\
    geom_hline(y=[hitter.sz_bottom.mean(), hitter.sz_top.mean()], color='red') +\
    geom_vline(x=[-1, 1], color='red') +\
    xlim(-2, 2) + ylim(0, 4) +\
    coord_equal()
# Out:
# <ggplot: (290971165)>

# %%
ggplot(aes(x='px', y='pz'), data=hitter) +\
    stat_bin2d() +\
    geom_hline(y=[hitter.sz_bottom.mean(), hitter.sz_top.mean()], color='red') +\
    geom_vline(x=[-1, 1], color='red') +\
    xlim(-2, 2) + ylim(0, 4) +\
    facet_wrap("f_pitch_type", scales="fixed") +\
    coord_equal()
# Out:
# <ggplot: (286306977)>

# %%
fastballs = df[df.f_pitch_type=='Fastball']

# %%
ggplot(aes(x='x', y='y', color='start_speed'), data=fastballs) +\
    geom_point() +\
    scale_color_gradient() +\
    coord_equal()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-864b6c3cc3e6> in <module>()
# ----> 1 ggplot(aes(x='x', y='y', color='start_speed'), data=fastballs) +    geom_point() +    scale_color_gradient() +    coord_equal()
#
# /usr/local/lib/python2.7/site-packages/IPython/core/displayhook.pyc in __call__(self, result)
#     245             self.start_displayhook()
#     246             self.write_output_prompt()
# --> 247             format_dict, md_dict = self.compute_format_data(result)
#     248             self.write_format_data(format_dict, md_dict)
#     249             self.update_user_ns(result)
#
# /usr/local/lib/python2.7/site-packages/IPython/core/displayhook.pyc in compute_format_data(self, result)
#     155
#     156         """
# --> 157         return self.shell.display_formatter.format(result)
#     158
#     159     def write_format_data(self, format_dict, md_dict=None):
#
# /usr/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     150             md = None
#     151             try:
# --> 152                 data = formatter(obj)
#     153             except:
#     154                 # FIXME: log the exception
#
# /usr/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     479                 type_pprinters=self.type_printers,
#     480                 deferred_pprinters=self.deferred_printers)
# --> 481             printer.pretty(obj)
#     482             printer.flush()
#     483             return stream.getvalue()
#
# /usr/local/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     360                             if callable(meth):
#     361                                 return meth(obj, self, cycle)
# --> 362             return _default_pprint(obj, self, cycle)
#     363         finally:
#     364             self.end_group()
#
# /usr/local/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
#     480     if getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     481         # A user-provided repr.
# --> 482         p.text(repr(obj))
#     483         return
#     484     p.begin_group(1, '<')
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ggplot-0.5.6-py2.7.egg/ggplot/ggplot.pyc in __repr__(self)
#     108     def __repr__(self):
#     109         """Print/show the plot"""
# --> 110         figure = self.draw()
#     111         # We're going to default to making the plot appear when __repr__ is
#     112         # called.
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ggplot-0.5.6-py2.7.egg/ggplot/ggplot.pyc in draw(self)
#     186             # Aes need to be initialized BEFORE we start faceting. This is b/c
#     187             # we want to have a consistent aes mapping across facets.
# --> 188             self.data, self.legend = assign_visual_mapping(self.data, self.aesthetics, self)
#     189
#     190             # Faceting just means doing an additional groupby. The
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ggplot-0.5.6-py2.7.egg/ggplot/components/__init__.pyc in assign_visual_mapping(data, aes, gg)
#      26     """
#      27     legend = {}
# ---> 28     data, legend['color'] = colors.assign_colors(data, aes, gg, 'color')
#      29     data, legend['fill'] = colors.assign_colors(data, aes, gg, 'fill')
#      30     data, legend['size'] = size.assign_sizes(data, aes)
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ggplot-0.5.6-py2.7.egg/ggplot/components/colors.pyc in assign_colors(data, aes, gg, aes_name)
#      84         if color_col in continuous_cols:
#      85             data, legend_entry = assign_continuous_colors(
# ---> 86                 data, gg, aes_name, color_col)
#      87         else:
#      88             data, legend_entry = assign_discrete_colors(
#
# /usr/local/Cellar/python/2.7.5/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ggplot-0.5.6-py2.7.egg/ggplot/components/colors.pyc in assign_continuous_colors(data, gg, aes_name, color_col)
#     123     _mcolumn = ':::%s_mapping:::' % aes_name
#     124     values = data[color_col].tolist()
# --> 125     values = [(i - min(values)) / (max(values) - min(values)) for i in values]
#     126     color_mapping = gg.colormap(values)[::, :3]
#     127     data[_mcolumn] = [rgb2hex(value) for value in color_mapping]
#
# KeyboardInterrupt:

# %%
ggplot(aes(x='start_speed', y='end_speed', color='start_speed - end_speed'), data=fastballs.head(10000)) +\
    geom_point() +\
    scale_color_gradient()
# Out:
# <ggplot: (287578977)>

# %%
ggplot(aes(x='start_speed', y='end_speed', color='start_speed - end_speed'), data=fastballs.head(10000)) +\
    geom_point() +\
    scale_color_gradient(low="blue", high="red") +\
    coord_equal()
# Out:
# <ggplot: (290971149)>

# %%
ggplot(aes(x='x', y='y', color='start_speed'), data=fastballs) +\
    geom_point() +\
    scale_color_gradient(low='yellow', high='red') +\
    coord_equal()
# Out:
# <ggplot: (274941157)>

# %%
ggplot(aes(x='start_speed'), data=df) +\
    geom_histogram()
# Out:
# binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# <ggplot: (275111153)>

# %%
ggplot(aes(x='pitch_type'), data=df) +\
    geom_bar()
# Out:
# <ggplot: (278153613)>

# %%
ggplot(aes(x='f_pitch_type'), data=df) +\
    geom_bar()
# Out:
# <ggplot: (275102617)>

# %%
ggplot(aes(x='f_pitch_type'), data=df) +\
    geom_bar()
# Out:
# <ggplot: (276519045)>

# %%
ggplot(aes(x='start_speed', color='factor(inning)'), data=df[df.inning < 10]) +\
    geom_density() +\
    scale_color_brewer(type='seq')
# Out:
# <ggplot: (275944537)>
